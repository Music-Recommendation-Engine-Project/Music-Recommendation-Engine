# %% [markdown]
# ## EDA

# %%
import matplotlib.pyplot as plt
# %matplotlib inline 
import pandas as pd
import numpy as np
from sklearn.model_selection import cross_val_score
from sklearn.model_selection import train_test_split
#from sklearn import cross_validation, linear_model
from sklearn.model_selection import cross_validate
from sklearn.cluster import KMeans
from sklearn import datasets
import random
import time

# %%
df = pd.read_parquet('../user_track_df.parquet', engine='pyarrow')
df.head()
# Out:
#                                     user_id             song_id  listen_count  \
# 0  b80344d063b5ccb3212f76538f3d9e43d87dca9e  SOBSUJE12A6D4F8CF5             2
# 1  b80344d063b5ccb3212f76538f3d9e43d87dca9e  SOBXHDL12A81C204C0             1
# 2  b80344d063b5ccb3212f76538f3d9e43d87dca9e  SOBXHDL12A81C204C0             1
# 3  b80344d063b5ccb3212f76538f3d9e43d87dca9e  SOBYHAJ12A6701BF1D             1
# 4  b80344d063b5ccb3212f76538f3d9e43d87dca9e  SOEWFWM12A8C1308BA             1
#
#              track_id    artist_name                track_name  \
# 0  TRPLAXZ128F4292406  Jorge Drexler  12 segundos de oscuridad
# 1  TRHNCIR128F42334A5     Kanye West                  Stronger
# 2  TRUATNS128F423457D     Kanye West                  Stronger
# 3  TRYBNIB128F428E704   Jack Johnson            Constellations
# 4  TRLQPQJ128F42AA94F    Gipsy Kings                       Soy
#
#                 track_uri  popularity  duration_ms  explicit  ... loudness  \
# 0  2ECKXkpPAxky87ohawpaeD          37       246826         0  ...   -8.176
# 1  4fzsfWzRhPawzqhX8Qt9F3          82       311867         1  ...   -7.858
# 2  4fzsfWzRhPawzqhX8Qt9F3          82       311867         1  ...   -7.858
# 3  3deZQXBY8CJFbrTc2PbU34          59       201640         0  ...  -12.640
# 4  076jKe7yfP979o1QLKMIA2          47       189987         0  ...  -12.321
#
#    mode  speechiness  acousticness  instrumentalness  liveness  valence  \
# 0     0       0.0327       0.11900          0.000412     0.103   0.0396
# 1     0       0.1530       0.00564          0.000000     0.408   0.4900
# 2     0       0.1530       0.00564          0.000000     0.408   0.4900
# 3     1       0.0355       0.46800          0.000043     0.117   0.4430
# 4     0       0.0653       0.29700          0.000267     0.127   0.9050
#
#      tempo  time_signature               artist_id
# 0  126.051               4  4ssUf5gLb1GBLxi1BhPrVt
# 1  103.992               4  5K4W6rqBFWDnAN6FQUkS6x
# 2  103.992               4  5K4W6rqBFWDnAN6FQUkS6x
# 3  122.012               4  3GBPw9NK25X1Wt2OUvOwY3
# 4  114.656               4  3jc496ljiyrS3ECrD7QiqL
#
# [5 rows x 24 columns]

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 11793648 entries, 0 to 11793647
# Data columns (total 24 columns):
#  #   Column            Dtype
# ---  ------            -----
#  0   user_id           object
#  1   song_id           object
#  2   listen_count      int64
#  3   track_id          object
#  4   artist_name       object
#  5   track_name        object
#  6   track_uri         object
#  7   popularity        int64
#  8   duration_ms       int64
#  9   explicit          int64
#  10  release_date      object
#  11  danceability      float64
#  12  energy            float64
#  13  key               int64
#  14  loudness          float64
#  15  mode              int64
#  16  speechiness       float64
#  17  acousticness      float64
#  18  instrumentalness  float64
#  19  liveness          float64
#  20  valence           float64
#  21  tempo             float64
#  22  time_signature    int64
#  23  artist_id         object
# dtypes: float64(9), int64(7), object(8)
# memory usage: 2.1+ GB

# %%
df.describe()
# Out:
#        listen_count    popularity   duration_ms      explicit  danceability  \
# count  1.179365e+07  1.179365e+07  1.179365e+07  1.179365e+07  1.179365e+07
# mean   2.893217e+00  5.773708e+01  2.434003e+05  8.264695e-02  5.704806e-01
# std    5.825543e+00  1.493103e+01  6.617471e+04  2.753478e-01  1.586017e-01
# min    1.000000e+00  0.000000e+00  3.082700e+04  0.000000e+00  0.000000e+00
# 25%    1.000000e+00  4.800000e+01  2.054530e+05  0.000000e+00  4.620000e-01
# 50%    1.000000e+00  5.800000e+01  2.359330e+05  0.000000e+00  5.770000e-01
# 75%    3.000000e+00  6.900000e+01  2.721330e+05  0.000000e+00  6.810000e-01
# max    2.213000e+03  8.600000e+01  1.777907e+06  1.000000e+00  9.800000e-01
#
#              energy           key      loudness          mode   speechiness  \
# count  1.179365e+07  1.179365e+07  1.179365e+07  1.179365e+07  1.179365e+07
# mean   6.731045e-01  5.344402e+00 -7.795270e+00  6.637429e-01  6.446345e-02
# std    2.134814e-01  3.572843e+00  3.714323e+00  4.724281e-01  6.526362e-02
# min    2.030000e-05  0.000000e+00 -3.765800e+01  0.000000e+00  0.000000e+00
# 25%    5.300000e-01  2.000000e+00 -9.502000e+00  0.000000e+00  3.240000e-02
# 50%    7.070000e-01  5.000000e+00 -6.981000e+00  1.000000e+00  4.120000e-02
# 75%    8.470000e-01  9.000000e+00 -5.201000e+00  1.000000e+00  6.460000e-02
# max    9.990000e-01  1.100000e+01  5.376000e+00  1.000000e+00  9.580000e-01
#
#        acousticness  instrumentalness      liveness       valence  \
# count  1.179365e+07      1.179365e+07  1.179365e+07  1.179365e+07
# mean   1.990057e-01      7.478830e-02  1.879835e-01  5.276782e-01
# std    2.662737e-01      2.024800e-01  1.451038e-01  2.447332e-01
# min    0.000000e+00      0.000000e+00  1.010000e-02  0.000000e+00
# 25%    6.200000e-03      0.000000e+00  9.340000e-02  3.220000e-01
# 50%    6.750000e-02      6.470000e-05  1.250000e-01  5.350000e-01
# 75%    2.920000e-01      8.080000e-03  2.580000e-01  7.260000e-01
# max    9.960000e-01      9.880000e-01  9.970000e-01  9.920000e-01
#
#               tempo  time_signature
# count  1.179365e+07    1.179365e+07
# mean   1.219446e+02    3.942510e+00
# std    2.772366e+01    2.748971e-01
# min    0.000000e+00    0.000000e+00
# 25%    1.001580e+02    4.000000e+00
# 50%    1.203360e+02    4.000000e+00
# 75%    1.399690e+02    4.000000e+00
# max    2.433720e+02    5.000000e+00

# %%
df.duplicated().any()
# Out:
# False

# %%
df.isnull().values.any()
# Out:
# False

# %%
df.eq(0).sum()
# Out:
# user_id                    0
# song_id                    0
# listen_count               0
# track_id                   0
# artist_name                0
# track_name                 0
# track_uri                  0
# popularity              4013
# duration_ms                0
# explicit            10818939
# release_date               0
# danceability               3
# energy                     0
# key                  1324577
# loudness                   0
# mode                 3965698
# speechiness                3
# acousticness              95
# instrumentalness     3446578
# liveness                   0
# valence                    3
# tempo                      3
# time_signature             3
# artist_id                  0
# dtype: int64

# %%
songs = df['song_id'].unique()
len(songs) ## return 19827 unique songs
# Out:
# 19827

# %%
users = df['user_id'].unique()
len(users) ## return 983357 unique users
# Out:
# 983357

# %%
#define number of rows and columns for subplots
nrow=8
ncol=2

# make a list of all columns
df_list = [df['duration_ms'], df['tempo'], df['popularity'], df['loudness'],
          df['key'], df['danceability'], df['energy'], df['mode'], df['speechiness'],
          df['acousticness'], df['instrumentalness'], df['liveness'], df['valence'],
          df['time_signature'], df['explicit'], df['listen_count']]
fig, axes = plt.subplots(nrow, ncol)

# plot counter
count=0
for r in range(nrow):
    for c in range(ncol):
        df_list[count].plot.box(ax=axes[r,c], figsize=(15,20))
        count+=1

# %%
#define number of rows and columns for subplots
nrow=8
ncol=2

# make a list of all columns
df_list = [df['duration_ms'], df['tempo'], df['popularity'], df['loudness'],
          df['key'], df['danceability'], df['energy'], df['mode'], df['speechiness'],
          df['acousticness'], df['instrumentalness'], df['liveness'], df['valence'],
          df['time_signature'], df['explicit'], df['listen_count']]
fig, axes = plt.subplots(nrow, ncol)

# plot counter
count=0
for r in range(nrow):
    for c in range(ncol):
        df_list[count].plot.hist(ax=axes[r,c], bins = 20, figsize=(15,20))
        count+=1

# %%
corr = df.corr(numeric_only=True)

# Fill diagonal and upper half with NaNs
mask = np.zeros_like(corr, dtype=bool)
mask[np.triu_indices_from(mask)] = True
corr[mask] = np.nan
(corr
 .style.format(precision=2)
 .background_gradient(cmap='coolwarm', axis=None, vmin=-1, vmax=1)
 .highlight_null(color='#f1f1f1')  # Color NaNs grey
)
# Out:
# <style type="text/css">
# #T_c9110_row0_col0, #T_c9110_row0_col1, #T_c9110_row0_col2, #T_c9110_row0_col3, #T_c9110_row0_col4, #T_c9110_row0_col5, #T_c9110_row0_col6, #T_c9110_row0_col7, #T_c9110_row0_col8, #T_c9110_row0_col9, #T_c9110_row0_col10, #T_c9110_row0_col11, #T_c9110_row0_col12, #T_c9110_row0_col13, #T_c9110_row0_col14, #T_c9110_row0_col15, #T_c9110_row1_col1, #T_c9110_row1_col2, #T_c9110_row1_col3, #T_c9110_row1_col4, #T_c9110_row1_col5, #T_c9110_row1_col6, #T_c9110_row1_col7, #T_c9110_row1_col8, #T_c9110_row1_col9, #T_c9110_row1_col10, #T_c9110_row1_col11, #T_c9110_row1_col12, #T_c9110_row1_col13, #T_c9110_row1_col14, #T_c9110_row1_col15, #T_c9110_row2_col2, #T_c9110_row2_col3, #T_c9110_row2_col4, #T_c9110_row2_col5, #T_c9110_row2_col6, #T_c9110_row2_col7, #T_c9110_row2_col8, #T_c9110_row2_col9, #T_c9110_row2_col10, #T_c9110_row2_col11, #T_c9110_row2_col12, #T_c9110_row2_col13, #T_c9110_row2_col14, #T_c9110_row2_col15, #T_c9110_row3_col3, #T_c9110_row3_col4, #T_c9110_row3_col5, #T_c9110_row3_col6, #T_c9110_row3_col7, #T_c9110_row3_col8, #T_c9110_row3_col9, #T_c9110_row3_col10, #T_c9110_row3_col11, #T_c9110_row3_col12, #T_c9110_row3_col13, #T_c9110_row3_col14, #T_c9110_row3_col15, #T_c9110_row4_col4, #T_c9110_row4_col5, #T_c9110_row4_col6, #T_c9110_row4_col7, #T_c9110_row4_col8, #T_c9110_row4_col9, #T_c9110_row4_col10, #T_c9110_row4_col11, #T_c9110_row4_col12, #T_c9110_row4_col13, #T_c9110_row4_col14, #T_c9110_row4_col15, #T_c9110_row5_col5, #T_c9110_row5_col6, #T_c9110_row5_col7, #T_c9110_row5_col8, #T_c9110_row5_col9, #T_c9110_row5_col10, #T_c9110_row5_col11, #T_c9110_row5_col12, #T_c9110_row5_col13, #T_c9110_row5_col14, #T_c9110_row5_col15, #T_c9110_row6_col6, #T_c9110_row6_col7, #T_c9110_row6_col8, #T_c9110_row6_col9, #T_c9110_row6_col10, #T_c9110_row6_col11, #T_c9110_row6_col12, #T_c9110_row6_col13, #T_c9110_row6_col14, #T_c9110_row6_col15, #T_c9110_row7_col7, #T_c9110_row7_col8, #T_c9110_row7_col9, #T_c9110_row7_col10, #T_c9110_row7_col11, #T_c9110_row7_col12, #T_c9110_row7_col13, #T_c9110_row7_col14, #T_c9110_row7_col15, #T_c9110_row8_col8, #T_c9110_row8_col9, #T_c9110_row8_col10, #T_c9110_row8_col11, #T_c9110_row8_col12, #T_c9110_row8_col13, #T_c9110_row8_col14, #T_c9110_row8_col15, #T_c9110_row9_col9, #T_c9110_row9_col10, #T_c9110_row9_col11, #T_c9110_row9_col12, #T_c9110_row9_col13, #T_c9110_row9_col14, #T_c9110_row9_col15, #T_c9110_row10_col10, #T_c9110_row10_col11, #T_c9110_row10_col12, #T_c9110_row10_col13, #T_c9110_row10_col14, #T_c9110_row10_col15, #T_c9110_row11_col11, #T_c9110_row11_col12, #T_c9110_row11_col13, #T_c9110_row11_col14, #T_c9110_row11_col15, #T_c9110_row12_col12, #T_c9110_row12_col13, #T_c9110_row12_col14, #T_c9110_row12_col15, #T_c9110_row13_col13, #T_c9110_row13_col14, #T_c9110_row13_col15, #T_c9110_row14_col14, #T_c9110_row14_col15, #T_c9110_row15_col15 {
#   background-color: #000000;
#   color: #f1f1f1;
#   background-color: #f1f1f1;
# }
# #T_c9110_row1_col0, #T_c9110_row13_col6 {
#   background-color: #dedcdb;
#   color: #000000;
# }
# #T_c9110_row2_col0, #T_c9110_row3_col0, #T_c9110_row5_col0, #T_c9110_row6_col0, #T_c9110_row6_col4, #T_c9110_row8_col0, #T_c9110_row9_col6, #T_c9110_row12_col0, #T_c9110_row12_col11, #T_c9110_row13_col0, #T_c9110_row14_col0, #T_c9110_row14_col11, #T_c9110_row14_col13 {
#   background-color: #dcdddd;
#   color: #000000;
# }
# #T_c9110_row2_col1, #T_c9110_row7_col4, #T_c9110_row11_col10, #T_c9110_row12_col3, #T_c9110_row13_col12, #T_c9110_row15_col9 {
#   background-color: #e2dad5;
#   color: #000000;
# }
# #T_c9110_row3_col1 {
#   background-color: #e9d5cb;
#   color: #000000;
# }
# #T_c9110_row3_col2, #T_c9110_row6_col3, #T_c9110_row6_col5, #T_c9110_row14_col8 {
#   background-color: #dfdbd9;
#   color: #000000;
# }
# #T_c9110_row4_col0, #T_c9110_row6_col2, #T_c9110_row7_col0, #T_c9110_row10_col0, #T_c9110_row12_col8, #T_c9110_row15_col0, #T_c9110_row15_col6, #T_c9110_row15_col12 {
#   background-color: #dddcdc;
#   color: #000000;
# }
# #T_c9110_row4_col1 {
#   background-color: #e5d8d1;
#   color: #000000;
# }
# #T_c9110_row4_col2 {
#   background-color: #d2dbe8;
#   color: #000000;
# }
# #T_c9110_row4_col3, #T_c9110_row14_col5 {
#   background-color: #f1ccb8;
#   color: #000000;
# }
# #T_c9110_row5_col1, #T_c9110_row7_col3, #T_c9110_row9_col5, #T_c9110_row12_col9, #T_c9110_row13_col9, #T_c9110_row15_col7 {
#   background-color: #ebd3c6;
#   color: #000000;
# }
# #T_c9110_row5_col2, #T_c9110_row8_col1, #T_c9110_row9_col0, #T_c9110_row11_col0 {
#   background-color: #dbdcde;
#   color: #000000;
# }
# #T_c9110_row5_col3, #T_c9110_row12_col7, #T_c9110_row13_col3 {
#   background-color: #e7d7ce;
#   color: #000000;
# }
# #T_c9110_row5_col4, #T_c9110_row6_col1, #T_c9110_row9_col1, #T_c9110_row9_col2, #T_c9110_row12_col6, #T_c9110_row14_col2 {
#   background-color: #d9dce1;
#   color: #000000;
# }
# #T_c9110_row7_col1, #T_c9110_row13_col5 {
#   background-color: #f6bfa6;
#   color: #000000;
# }
# #T_c9110_row7_col2, #T_c9110_row10_col6, #T_c9110_row13_col1, #T_c9110_row15_col8 {
#   background-color: #d7dce3;
#   color: #000000;
# }
# #T_c9110_row7_col5 {
#   background-color: #df634e;
#   color: #f1f1f1;
# }
# #T_c9110_row7_col6, #T_c9110_row12_col2, #T_c9110_row15_col2 {
#   background-color: #dadce0;
#   color: #000000;
# }
# #T_c9110_row8_col2, #T_c9110_row12_col1 {
#   background-color: #d3dbe7;
#   color: #000000;
# }
# #T_c9110_row8_col3, #T_c9110_row11_col4, #T_c9110_row11_col5 {
#   background-color: #d4dbe6;
#   color: #000000;
# }
# #T_c9110_row8_col4, #T_c9110_row8_col7, #T_c9110_row10_col4, #T_c9110_row11_col3, #T_c9110_row11_col9, #T_c9110_row12_col4 {
#   background-color: #d5dbe5;
#   color: #000000;
# }
# #T_c9110_row8_col5, #T_c9110_row10_col3, #T_c9110_row12_col10 {
#   background-color: #cfdaea;
#   color: #000000;
# }
# #T_c9110_row8_col6, #T_c9110_row13_col10 {
#   background-color: #c4d5f3;
#   color: #000000;
# }
# #T_c9110_row9_col3 {
#   background-color: #f7ac8e;
#   color: #000000;
# }
# #T_c9110_row9_col4, #T_c9110_row15_col5 {
#   background-color: #efcfbf;
#   color: #000000;
# }
# #T_c9110_row9_col7, #T_c9110_row10_col8 {
#   background-color: #e6d7cf;
#   color: #000000;
# }
# #T_c9110_row9_col8, #T_c9110_row13_col8, #T_c9110_row14_col9, #T_c9110_row15_col11 {
#   background-color: #d8dce2;
#   color: #000000;
# }
# #T_c9110_row10_col1, #T_c9110_row11_col1, #T_c9110_row15_col10 {
#   background-color: #c6d6f1;
#   color: #000000;
# }
# #T_c9110_row10_col2, #T_c9110_row10_col9 {
#   background-color: #d1dae9;
#   color: #000000;
# }
# #T_c9110_row10_col5 {
#   background-color: #6b8df0;
#   color: #f1f1f1;
# }
# #T_c9110_row10_col7 {
#   background-color: #85a8fc;
#   color: #f1f1f1;
# }
# #T_c9110_row11_col2 {
#   background-color: #edd2c3;
#   color: #000000;
# }
# #T_c9110_row11_col6, #T_c9110_row14_col1 {
#   background-color: #e1dad6;
#   color: #000000;
# }
# #T_c9110_row11_col7 {
#   background-color: #bad0f8;
#   color: #000000;
# }
# #T_c9110_row11_col8, #T_c9110_row15_col14 {
#   background-color: #d6dce4;
#   color: #000000;
# }
# #T_c9110_row12_col5 {
#   background-color: #f0cdbb;
#   color: #000000;
# }
# #T_c9110_row13_col2 {
#   background-color: #b9d0f9;
#   color: #000000;
# }
# #T_c9110_row13_col4 {
#   background-color: #f49a7b;
#   color: #000000;
# }
# #T_c9110_row13_col7 {
#   background-color: #ecd3c5;
#   color: #000000;
# }
# #T_c9110_row13_col11, #T_c9110_row14_col3 {
#   background-color: #cedaeb;
#   color: #000000;
# }
# #T_c9110_row14_col4 {
#   background-color: #b6cefa;
#   color: #000000;
# }
# #T_c9110_row14_col6, #T_c9110_row14_col12 {
#   background-color: #e0dbd8;
#   color: #000000;
# }
# #T_c9110_row14_col7 {
#   background-color: #ead4c8;
#   color: #000000;
# }
# #T_c9110_row14_col10 {
#   background-color: #c9d7f0;
#   color: #000000;
# }
# #T_c9110_row15_col1 {
#   background-color: #e4d9d2;
#   color: #000000;
# }
# #T_c9110_row15_col3 {
#   background-color: #e3d9d3;
#   color: #000000;
# }
# #T_c9110_row15_col4, #T_c9110_row15_col13 {
#   background-color: #edd1c2;
#   color: #000000;
# }
# </style>
# <table id="T_c9110">
#   <thead>
#     <tr>
#       <th class="blank level0" >&nbsp;</th>
#       <th id="T_c9110_level0_col0" class="col_heading level0 col0" >listen_count</th>
#       <th id="T_c9110_level0_col1" class="col_heading level0 col1" >popularity</th>
#       <th id="T_c9110_

# %%
df.plot.scatter(x = 'loudness', y = 'energy',
                  color = 'sandybrown', title = 'Loudness vs Energy')
df.plot.scatter(x = 'valence', y = 'danceability',
                  color = 'sandybrown', title = 'Valence vs Danceability')
df.plot.scatter(x = 'acousticness', y = 'energy',
                  color = 'sandybrown', title = 'Acousticness vs Energy')
# Out:
# <Axes: title={'center': 'Acousticness vs Energy'}, xlabel='acousticness', ylabel='energy'>

# %%
#create reference table of song id and its popularity
unique_indexes = df.song_id.drop_duplicates().index
df[['song_id','popularity']].loc[unique_indexes]
ref = df[['song_id','popularity']].loc[unique_indexes] #the ref table
ref.index = range(len(ref)) #make index as 0,1,...

# %%
#sum groupby song_id
df_pop = df[['song_id','listen_count']].groupby('song_id').sum()
df_pop.reset_index(inplace = True)
#order descending
df_pop.sort_values(by = ['listen_count'], ascending = False, inplace = True)
#merge
df_pop = df_pop.merge(ref, on = 'song_id')

# %%
df_pop.head()
# Out:
#               song_id  listen_count  popularity
# 0  SONYKOW12AB01849C9        292642          77
# 1  SODGVGW12AC9075A8D        221514          70
# 2  SOPXKYD12A6D4FA876        219132          86
# 3  SOFLJQZ12A6D4FADA6        185653          38
# 4  SONIQRE12AF72A2B02        182896          81

# %%
df_pop.iloc[:10].plot.bar(x = 'song_id', y = 'listen_count', 
                                 color = 'skyblue', 
                                 title = 'Top 10 Songs by Listen Count')
# Out:
# <Axes: title={'center': 'Top 10 Songs by Listen Count'}, xlabel='song_id'>
